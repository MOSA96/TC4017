# %%
# !uv run pylint convert_numbers.py
# Out:
# --------------------------------------------------------------------
# Your code has been rated at 10.00/10 (previous run: 10.00/10, +0.00)

# %%
# !uv run pylint convert_numbers_tests.py
# Out:
# --------------------------------------------------------------------
# Your code has been rated at 10.00/10 (previous run: 10.00/10, +0.00)

# %%
# !uv run pytest convert_numbers_tests.py -v
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.12.9, pytest-9.0.2, pluggy-1.6.0 -- /mnt/d/Programacion/maestria/quality/.venv/bin/python3
# cachedir: .pytest_cache
# rootdir: /mnt/d/Programacion/maestria/quality
# configfile: pyproject.toml
# collected 9 items
#
# convert_numbers_tests.py::test_numbers_to_binary_zero PASSED             [ 11%]
# convert_numbers_tests.py::test_numbers_to_hexadecimal_zero PASSED        [ 22%]
# convert_numbers_tests.py::test_numbers_to_binary_negative_numbers PASSED [ 33%]
# convert_numbers_tests.py::test_numbers_to_hexadecimal_negative_numbers PASSED [ 44%]
# convert_numbers_tests.py::test_file_to_list_invalid_and_empty_lines PASSED [ 55%]
# convert_numbers_tests.py::test_converters_pass_through_nan_for_non_ints PASSED [ 66%]
# convert_numbers_tests.py::test_file_to_list_missing_file_raises PASSED   [ 77%]
# convert_numbers_tests.py::test_arrays_to_file_creates_output_file PASSED [ 88%]
# ...

# %%
# !uv run python convert_numbers.py tests_files/TC1.txt
# Out:
# Original: [6980368, 5517055, 1336159, 6750185, 1771937, 360952, 5672561, 916583, 2700138, 9645053, 1181110, 1492185, 4018595, 7654888, 7062453, 2478010, 6134768, 8420417, 2917489, 3340773, 1115956, 9172192, 6271996, 8686939, 50986, 9376410, 5962327, 7686891, 6615183, 1864844, 3329962, 3942794, 2614836, 7406772, 2384190, 398347, 8698503, 9551696, 1019556, 1677430, 3479629, 9309008, 5266170, 4094340, 1754055, 5861132, 4471329, 8826052, 7469325, 1973172, 53145, 3897508, 7773386, 6089829, 4223424, 9761752, 7930799, 3597495, 9302948, 2288712, 197187, 5266939, 221545, 7957027, 3195361, 7106269, 9633312, 9713704, 91925, 4418686, 9682250, 2583824, 4979126, 6280954, 1228610, 705518, 1017653, 500098, 7210727, 4250898, 4055028, 2754240, 452999, 6831458, 207636, 7280635, 3308937, 4303570, 8375055, 1457960, 5197625, 3144371, 6674138, 2692106, 2276769, 1940971, 3288264, 4819803, 9431005, 3992019, 8184782, 2847975, 7891025, 900082, 1831532, 8428253, 2905752, 9763121, 257890, 4699761, 359541, 344615
# ...

# %%
# !uv run python convert_numbers.py tests_files/TC2.txt
# Out:
# Original: [7116776, 1666340, 8886983, 839365, 924280, 1026310, 1615293, 1063875, 679035, 5201970, 593979, 801371, 3796878, 7489201, 9740020, 9128737, 5473463, 8701957, 8238050, 8679038, 385912, 5867340, 4894542, 8999451, 4392535, 2078131, 3070124, 7451998, 5635510, 1233932, 6089867, 1792316, 6298637, 2408038, 8510100, 991581, 6455739, 7829175, 6328931, 9982305, 2292022, 1070496, 8518360, 6378470, 7756258, 7111767, 2685897, 617946, 246280, 6075442, 991323, 6754202, 3103178, 3228842, 6786623, 5329085, 2334647, 7253396, 6516953, 5972725, 5828037, 6642265, 2559699, 6597631, 5826202, 4642335, 1862900, 6039635, 3358744, 4965249, 6621475, 3336153, 1044743, 6201477, 6297100, 885678, 8546891, 6683923, 7064472, 3430021, 9764122, 9958605, 1006022, 5276496, 8876232, 3364648, 3539979, 3003857, 4481634, 9035781, 3767021, 4993901, 8698377, 4626501, 1755352, 2755340, 5150616, 9345169, 848948, 2708748, 8372451, 3523015, 2624283, 8795348, 2318100, 4750861, 3770597, 1053352, 833307, 4632526, 2212917, 5
# ...

# %%
# !uv run python convert_numbers.py tests_files/TC3.txt
# Out:
# Original: [-39, -36, 8, 34, 17, 49, 5, 39, 0, 33, 12, -6, 27, -4, -38, 26, 49, 29, 42, -16, -28, 34, 20, 0, 25, 45, 3, -46, -46, 29, 33, 29, 26, -5, -36, 12, 45, -50, 0, -6, -39, 35, 26, -35, -42, 14, -3, 22, -47, 12, -17, -31, -25, -35, -18, 14, 37, -8, -41, -50, -9, 2, 12, -39, -17, 0, 27, 28, 45, -44, 28, 35, -33, 43, -4, 23, -49, 49, -7, -38, -45, 5, -21, 26, -2, -24, 6, -45, -4, 15, 0, -17, -35, 43, 45, -35, -8, 28, 47, 34, -24, -42, -13, 14, -45, -35, 27, -12, -19, -20, -14, 20, 30, 12, -36, -47, -27, -3, 6, 36, 9, -16, 36, -27, 7, -6, -5, 5, 47, 23, -48, -24, 40, -4, -18, -19, 14, 15, 1, 24, -9, -50, 18, 15, 30, 44, 9, 19, 33, 41, -24, 43, 48, -23, 7, 28, 8, -2, 37, 42, -17, -6, 36, 22, 27, 31, -47, -43, 0, 27, 30, 12, -15, -19, -42, -37, 31, -10, 18, 33, -15, 17, 25, -25, -5, 33, -13, 33, -10, 47, 47, -13, -32, 1, 1, -25, -33, 16, 17, 4]
# ...

# %%
# !uv run python convert_numbers.py tests_files/TC4.txt
# Out:
# [ERROR] Line 8: invalid integer 'ABC' -> treated as nan
# [ERROR] Line 21: invalid integer 'ERR' -> treated as nan
# [ERROR] Line 41: invalid integer 'VAL' -> treated as nan
# Original: [-39, -36, 8, 34, 17, 49, 5, 'nan', 0, 33, 12, -6, 27, -4, -38, 26, 49, 29, 42, -16, 'nan', 34, 20, 0, 25, 45, 3, -46, -46, 29, 33, 29, 26, -5, -36, 12, 45, -50, 0, -6, 'nan']
# Binary: ['-100111', '-100100', '1000', '100010', '10001', '110001', '101', 'nan', '0', '100001', '1100', '-110', '11011', '-100', '-100110', '11010', '110001', '11101', '101010', '-10000', 'nan', '100010', '10100', '0', '11001', '101101', '11', '-101110', '-101110', '11101', '100001', '11101', '11010', '-101', '-100100', '1100', '101101', '-110010', '0', '-110', 'nan']
# ...
