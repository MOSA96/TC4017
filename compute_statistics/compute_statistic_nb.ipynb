# %%
# !uv run pylint compute_statistics.py
# Out:
# --------------------------------------------------------------------
# Your code has been rated at 10.00/10 (previous run: 0.00/10, +10.00)

# %%
# !uv run pylint compute_statistics_tests.py
# Out:
# --------------------------------------------------------------------
# Your code has been rated at 10.00/10 (previous run: 10.00/10, +0.00)

# %%
# !uv run pytest compute_statistics_tests.py -v
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.12.9, pytest-9.0.2, pluggy-1.6.0 -- /mnt/d/Programacion/maestria/quality/.venv/bin/python3
# cachedir: .pytest_cache
# rootdir: /mnt/d/Programacion/maestria/quality
# configfile: pyproject.toml
# collected 8 items
#
# compute_statistics_tests.py::test_compute_mean_with_floats PASSED        [ 12%]
# compute_statistics_tests.py::test_compute_median_even_count PASSED       [ 25%]
# compute_statistics_tests.py::test_compute_mode_no_mode_all_unique PASSED [ 37%]
# compute_statistics_tests.py::test_compute_variance_simple_case PASSED    [ 50%]
# compute_statistics_tests.py::test_compute_standard_deviation_matches_sqrt PASSED [ 62%]
# compute_statistics_tests.py::test_file_to_list_invalid_and_empty_lines PASSED [ 75%]
# compute_statistics_tests.py::test_statistics_to_file_creates_output_file PASSED [ 87%]
# ...

# %%
# !uv run python compute_statistics.py tests_files/TC1.txt
# Out:
# [ERROR] Line 400: invalid float '405s' -> treated as nan
# Valid numbers: 399
# Invalid lines: 1
# Descriptive Statistics
# ----------------------
# Mean: 241.91
# Median: 239.00
# Mode: [170.0, 393.0]
# Variance: 21086.31
# Standard Deviation: 145.21
# Execution took 0.006888 seconds

# %%
# !uv run python compute_statistics.py tests_files/TC2.txt
# Out:
# Valid numbers: 1977
# Invalid lines: 0
# Descriptive Statistics
# ----------------------
# Mean: 250.78
# Median: 247.00
# Mode: [230.0]
# Variance: 20785.37
# Standard Deviation: 144.17
# Execution took 0.006936 seconds

# %%
# !uv run python compute_statistics.py tests_files/TC3.txt
# Out:
# Valid numbers: 12624
# Invalid lines: 0
# Descriptive Statistics
# ----------------------
# Mean: 249.78
# Median: 249.00
# Mode: [94.0]
# Variance: 21117.28
# Standard Deviation: 145.32
# Execution took 0.012611 seconds

# %%
# !uv run python compute_statistics.py tests_files/TC4.txt
# Out:
# Valid numbers: 12624
# Invalid lines: 0
# Descriptive Statistics
# ----------------------
# Mean: 149.00
# Median: 147.75
# Mode: [123.75]
# Variance: 17007.92
# Standard Deviation: 130.41
# Execution took 0.013463 seconds

# %%
# !uv run python compute_statistics.py tests_files/TC5.txt
# Out:
# [ERROR] Line 5: invalid float 'ABA' -> treated as nan
# [ERROR] Line 155: invalid float '23,45' -> treated as nan
# [ERROR] Line 232: invalid float '11;54' -> treated as nan
# [ERROR] Line 239: invalid float 'll' -> treated as nan
# Valid numbers: 307
# Invalid lines: 4
# Descriptive Statistics
# ----------------------
# Mean: 241.50
# Median: 241.00
# Mode: [11.0, 19.0, 46.0, 56.0, 64.0, 76.0, 96.0, 166.0, 170.0, 211.0, 215.0, 268.0, 277.0, 278.0, 290.0, 368.0, 375.0, 393.0, 466.0]
# Variance: 21160.02
# Standard Deviation: 145.46
# Execution took 0.005556 seconds

# %%
# !uv run python compute_statistics.py tests_files/TC6.txt
# Out:
# Valid numbers: 3000
# Invalid lines: 0
# Descriptive Statistics
# ----------------------
# Mean: 187906599279774728192.00
# Median: 188008049965542998016.00
# Mode: nan
# Variance: 11530904699530646862954721780958962384896.00
# Standard Deviation: 10738991852412602736572475899904.00
# Execution took 0.008798 seconds

# %%
# !uv run python compute_statistics.py tests_files/TC7.txt
# Out:
# [ERROR] Line 183: invalid float 'ABBA' -> treated as nan
# [ERROR] Line 229: invalid float 'ERROR' -> treated as nan
# Valid numbers: 12767
# Invalid lines: 2
# Descriptive Statistics
# ----------------------
# Mean: 247467395499714904064.00
# Median: 246640973074290016256.00
# Mode: nan
# Variance: 20910793147136483762414542324695312629760.00
# Standard Deviation: 19474693711042854713662101258240.00
# Execution took 0.018648 seconds
